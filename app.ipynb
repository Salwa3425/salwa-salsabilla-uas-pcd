# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# === KONFIGURASI PROYEK ===
NIM = 24146001  

# Path lokasi folder dataset yang sudah diekstrak
DATASET_DIR = './flowers'

# Nama kelas sesuai folder dataset
CATEGORIES = ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# Dimensi gambar setelah di-resize (64x64 piksel agar efisien untuk MLP)
IMG_SIZE = 64

data = []
labels = []
original_images = []  # Disimpan untuk visualisasi plot di akhir

print("Memulai proses pemuatan dan preprocessing data...")

for category_idx, category in enumerate(CATEGORIES):
    folder_path = os.path.join(DATASET_DIR, category)
    
    if not os.path.exists(folder_path):
        print(f"Peringatan: Folder {folder_path} tidak ditemukan!")
        continue
        
    print(f"Memproses kelas: {category}...")
    
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        
        # 1. BACA GAMBAR
        img = cv2.imread(img_path)
        if img is None:
            continue  # Abaikan file jika terdistorsi / bukan gambar
            
        # 2. KONVERSI WARNA BGR ke RGB
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # 3. RESIZE GAMBAR
        img_resized = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))
        
        # 4. EKSTRAKSI FITUR (FLATTEN)
        # Mengubah matriks 3D (64, 64, 3) menjadi Vektor 1D (12288,) untuk MLP
        img_flatten = img_resized.flatten()
        
        data.append(img_flatten)
        labels.append(category_idx)
        original_images.append(img_resized)

# Konversi ke NumPy Array
X = np.array(data, dtype='float32')
y = np.array(labels)
original_images = np.array(original_images)

# 5. NORMALISASI PIKSEL (Ubah rentang 0-255 menjadi 0.0 - 1.0)
X = X / 255.0

print(f"\nSelesai! Total gambar yang diproses: {X.shape[0]}")
print(f"Dimensi Vektor Fitur: {X.shape}")

# Pembagian data 80% train dan 20% test
# random_state menggunakan NIM sesuai instruksi soal
X_train, X_test, y_train, y_test, orig_train, orig_test = train_test_split(
    X, 
    y, 
    original_images,
    test_size=0.2, 
    random_state=NIM,
    stratify=y  # Menjaga proporsi tiap kelas seimbang
)

print(f"Jumlah Data Training (80%) : {X_train.shape[0]}")
print(f"Jumlah Data Testing  (20%) : {X_test.shape[0]}")

print("Melatih model MLPClassifier...")

# Inisialisasi Model MLP
mlp = MLPClassifier(
    hidden_layer_sizes=(256, 128, 64),  # 3 Hidden Layer
    activation='relu',                  # Fungsi aktivasi ReLU
    solver='adam',                      # Optimizer Adam
    max_iter=300,                       # Jumlah iterasi max
    random_state=NIM,                   # NIM sebagai random state
    verbose=True                        # Menampilkan proses training tiap epoch
)

# Proses Training
mlp.fit(X_train, y_train)

print("\nProses Pelatihan Selesai!")

# Prediksi pada Data Testing
y_pred = mlp.predict(X_test)

# Menampilkan Laporan Klasifikasi dengan ketelitian 4 angka desimal
print("="*60)
print("                     CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_test, y_pred, target_names=CATEGORIES, digits=4))

# Membuat Plot Grid 5x5
plt.figure(figsize=(15, 15))

for row_idx, category in enumerate(CATEGORIES):
    # Cari indeks data testing yang tergolong dalam kelas saat ini
    class_indices = np.where(y_test == row_idx)[0]
    
    # Ambil 5 gambar secara acak dengan seed NIM agar hasil konsisten
    np.random.seed(NIM)
    selected_indices = np.random.choice(class_indices, size=5, replace=False)
    
    for col_idx, img_idx in enumerate(selected_indices):
        plot_position = row_idx * 5 + col_idx + 1
        plt.subplot(5, 5, plot_position)
        
        # Tampilkan Gambar
        plt.imshow(orig_test[img_idx])
        plt.axis('off')
        
        true_label = CATEGORIES[y_test[img_idx]]
        pred_label = CATEGORIES[y_pred[img_idx]]
        
        # Warna teks: Hijau jika prediksi benar, Merah jika salah
        text_color = 'green' if true_label == pred_label else 'red'
        
        plt.title(f"True: {true_label}\nPred: {pred_label}", color=text_color, fontsize=10)

plt.suptitle("Hasil Prediksi 25 Gambar Acak (5 Per Kelas)", fontsize=16, y=0.92)
plt.tight_layout()
plt.show()
# Out:
# Memulai proses pemuatan dan preprocessing data...
# Memproses kelas: daisy...
# Memproses kelas: dandelion...
# Memproses kelas: rose...
# Memproses kelas: sunflower...
# Memproses kelas: tulip...
#
# Selesai! Total gambar yang diproses: 4317
# Dimensi Vektor Fitur: (4317, 12288)
# Jumlah Data Training (80%) : 3453
# Jumlah Data Testing  (20%) : 864
# Melatih model MLPClassifier...
# Iteration 1, loss = 2.61831617
# Iteration 2, loss = 1.40567720
# Iteration 3, loss = 1.30574310
# Iteration 4, loss = 1.24925363
# Iteration 5, loss = 1.20211565
# Iteration 6, loss = 1.24787974
# Iteration 7, loss = 1.15188956
# Iteration 8, loss = 1.14345384
# Iteration 9, loss = 1.09965789
# Iteration 10, loss = 1.07861757
# Iteration 11, loss = 1.03922701
# Iteration 12, loss = 1.02675128
# Iteration 13, loss = 1.08745205
# Iteration 14, loss = 1.06184983
# Iteration 15, loss = 1.03568995
# Iteration 16, loss = 0.94014609
# Iteration 17, loss = 0.93256634
# Iteration 18, loss = 0.95729965
# Iteration 19, loss = 0.90967304
# Iteration 20, loss = 0.87827206
# Iteration 21, loss = 0.84813553
# Iteration 22, loss = 0.83396220
# Iteration 23, loss = 1.01968133
# Iteration 24, loss = 0.86951125
# Iteration 25, loss = 0.75653142
# Iteration 26, loss = 0.71948630
# Iteration 27, loss = 0.86519647
# Iteration 28, loss = 0.78877115
# Iteration 29, loss = 0.73410505
# Iteration 30, loss = 0.65871227
# Iteration 31, loss = 0.64889210
# Iteration 32, loss = 0.64685756
# Iteration 33, loss = 0.76699716
# Iteration 34, loss = 0.71353340
# Iteration 35, loss = 0.62785268
# Iteration 36, loss = 0.61652803
# Iteration 37, loss = 0.52183300
# Iteration 38, loss = 0.53892761
# Iteration 39, loss = 0.50870746
# Iteration 40, loss = 0.62952667
# Iteration 41, loss = 0.49701044
# Iteration 42, loss = 0.46751544
# Iteration 43, loss = 0.41961154
# Iteration 44, loss = 0.43699431
# Iteration 45, loss = 0.44934046
# Iteration 46, loss = 0.43336689
# Iteration 47, loss = 0.32534137
# Iteration 48, loss = 0.37727809
# Iteration 49, loss = 0.38329676
# Iteration 50, loss = 0.31770611
# Iteration 51, loss = 0.38919473
# Iteration 52, loss = 0.71207190
# Iteration 53, loss = 0.38137126
# Iteration 54, loss = 0.37856165
# Iteration 55, loss = 0.45261502
# Iteration 56, loss = 0.29826522
# Iteration 57, loss = 0.22173534
# Iteration 58, loss = 0.21066706
# Iteration 59, loss = 0.21157154
# Iteration 60, loss = 0.18715948
# Iteration 61, loss = 0.15291260
# Iteration 62, loss = 0.24453494
# Iteration 63, loss = 0.20348054
# Iteration 64, loss = 0.11774740
# Iteration 65, loss = 0.11929122
# Iteration 66, loss = 0.53370386
# Iteration 67, loss = 0.60751200
# Iteration 68, loss = 0.34203374
# Iteration 69, loss = 0.25316232
# Iteration 70, loss = 0.35794836
# Iteration 71, loss = 0.27026474
# Iteration 72, loss = 0.24232113
# Iteration 73, loss = 0.33986327
# Iteration 74, loss = 0.19905281
# Iteration 75, loss = 0.13990599
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# Proses Pelatihan Selesai!
# ============================================================
#                      CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#        daisy     0.3684    0.3660    0.3672       153
#    dandelion     0.4648    0.7238    0.5661       210
#         rose     0.4681    0.4204    0.4430       157
#    sunflower     0.6119    0.5578    0.5836       147
#        tulip     0.5727    0.3198    0.4104       197
#
#     accuracy                         0.4850       864
#    macro avg     0.4972    0.4776    0.4741       864
# weighted avg     0.4980    0.4850    0.4760       864
